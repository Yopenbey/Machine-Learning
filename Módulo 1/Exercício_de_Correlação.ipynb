# %%
import pandas as pd
pd.set_option('display.width', 420)
pd.set_option('display.max_columns', 47)
colunas = ['preg', 'pres', 'plas', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dados = pd.read_csv('2015-building-energy-benchmarking.csv')
dados.head()
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType           PropertyName TaxParcelIdentificationNumber                                           Location  CouncilDistrictCode Neighborhood  YearBuilt  NumberofBuildings  NumberofFloors  PropertyGFATotal  PropertyGFAParking  PropertyGFABuilding(s)      ListOfAllPropertyUseTypes LargestPropertyUseType  LargestPropertyUseTypeGFA  \
# 0              1      2015  NonResidential               Hotel   MAYFLOWER PARK HOTEL                     659000030  {'latitude': '47.61219025', 'longitude': '-122...                    7     DOWNTOWN       1927                  1            12.0             88434                   0                   88434                          Hotel                  Hotel                    88434.0
# ...

# %%
pd.set_option('display.max_columns', 47)
print(dados.corr(method = 'pearson'))
# Out:
#                                                     OSEBuildingID  DataYear  CouncilDistrictCode  YearBuilt  NumberofBuildings  NumberofFloors  PropertyGFATotal  PropertyGFAParking  PropertyGFABuilding(s)  LargestPropertyUseTypeGFA  SecondLargestPropertyUseTypeGFA  ThirdLargestPropertyUseTypeGFA  ENERGYSTARScore  \
# OSEBuildingID                                            1.000000       NaN            -0.092519   0.134578          -0.000676       -0.113519         -0.268611           -0.179414               -0.261334                  -0.252482                        -0.223600                       -0.180031         0.074262
# DataYear                                                      NaN       NaN                  NaN        NaN                NaN             NaN               NaN                 NaN                     NaN                        NaN                              NaN                             NaN              NaN
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 47)
dados = pd.read_csv('2015-building-energy-benchmarking.csv')
plt.figure(figsize=(5,5))
sns.heatmap(dados.corr())
plt.show
# Out:
# <function matplotlib.pyplot.show>
