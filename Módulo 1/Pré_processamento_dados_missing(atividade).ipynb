# %%
import pandas as pd
import statistics
from fractions import Fraction as F
from decimal import Decimal as D
dados = pd.read_csv('2015-building-energy-benchmarking.csv')
dados.head()
# Out:
#    OSEBuildingID  DataYear  ... SPD Beats Zip Codes
# 0              1      2015  ...      31.0     18081
# 1              2      2015  ...      31.0     18081
# 2              3      2015  ...      31.0     18081
# 3              5      2015  ...      31.0     18081
# 4              8      2015  ...      31.0     19576
#
# [5 rows x 47 columns]

# %%
porcntagem = (dados.isnull().sum() / len(dados['OSEBuildingID'])*100)
print(porcntagem)
# Out:
# OSEBuildingID                                                     0.000000
# DataYear                                                          0.000000
# BuildingType                                                      0.000000
# PrimaryPropertyType                                               0.000000
# PropertyName                                                      0.000000
# TaxParcelIdentificationNumber                                     0.059880
# Location                                                          0.000000
# CouncilDistrictCode                                               0.000000
# Neighborhood                                                      0.000000
# YearBuilt                                                         0.000000
# NumberofBuildings                                                 0.000000
# NumberofFloors                                                    0.239521
# ...

# %%
dados['ENERGYSTARScore'].fillna(dados['ENERGYSTARScore'].median(), inplace = True)
porcntagem = (dados.isnull().sum() / len(dados['OSEBuildingID'])*100)
print(porcntagem)
# Out:
# OSEBuildingID                                                     0.000000
# DataYear                                                          0.000000
# BuildingType                                                      0.000000
# PrimaryPropertyType                                               0.000000
# PropertyName                                                      0.000000
# TaxParcelIdentificationNumber                                     0.059880
# Location                                                          0.000000
# CouncilDistrictCode                                               0.000000
# Neighborhood                                                      0.000000
# YearBuilt                                                         0.000000
# NumberofBuildings                                                 0.000000
# NumberofFloors                                                    0.239521
# ...

# %%
dados.head()
# Out:
#    OSEBuildingID  DataYear  ... SPD Beats Zip Codes
# 0              1      2015  ...      31.0     18081
# 1              2      2015  ...      31.0     18081
# 2              3      2015  ...      31.0     18081
# 3              5      2015  ...      31.0     18081
# 4              8      2015  ...      31.0     19576
#
# [5 rows x 47 columns]
